# %%
#Import the libraries
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler


# Import MNIST Dataset for  training
from keras.datasets import mnist
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
# Normalizing the pixel values.

train_X = train_X.reshape((train_X.shape[0],784))
test_X = test_X.reshape((test_X.shape[0],784))
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
train_X = scaler_X.fit_transform(train_X)
test_X = scaler_y.fit_transform(test_X)

# %%
# tf Sequential model with 28x28 dimensions
tf.random.set_seed(34)
model = Sequential(
    [
        tf.keras.Input(shape=(784,)),
        # tf.keras.layers.Flatten(),
        Dense(units = 128, activation = 'relu', name="l0"),
        Dense(units = 64, activation = 'relu', name="l1"),
        Dense(units = 10, activation = 'softmax', name="l2")
    ], name="my_model"
)
model.summary()
# Out:
# Model: "my_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ l0 (Dense)                      │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ l1 (Dense)                      │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ l2 (Dense)                      │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Load the model, if already trained
model = tf.keras.models.load_model('model/my_model.keras')

# %%
# Training, using ADAM optimizer 
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
)

history = model.fit(
    train_X,train_y,
    epochs=20,
    validation_data=(test_X,test_y),
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 692us/step - loss: 0.5365 - val_loss: 0.1499
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 634us/step - loss: 0.1423 - val_loss: 0.1076
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 697us/step - loss: 0.0942 - val_loss: 0.0920
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 628us/step - loss: 0.0689 - val_loss: 0.0857
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 622us/step - loss: 0.0517 - val_loss: 0.0873
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 664us/step - loss: 0.0394 - val_loss: 0.0849
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 636us/step - loss: 0.0296 - val_loss: 0.0891
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - loss: 0.0218 - val_loss: 0.0916
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 623us/step - loss: 0.0181 - val_loss: 0.0959
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 636us/step - loss: 0.0150 - val_loss: 0.1122
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 650us/step - loss: 0.0141 - val_loss: 0.1034
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 640us/step - loss: 0.0132 - val_loss: 0.1018
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 627us/step - loss: 0.0089 - val_loss: 0.1048
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step - loss: 0.0096 - val_loss: 0.1067
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - loss: 0.0069 - val_loss: 0.1222
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 660us/step - loss: 0.0079 - val_loss: 0.1157
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - loss: 0.0079 - val_loss: 0.1146
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - loss: 0.0085 - val_loss: 0.1234
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 670us/step - loss: 0.0055 - val_loss: 0.1214
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step - loss: 0.0074 - val_loss: 0.1206

# %%
# save the trained model

model.save_weights('model/my_model.weights.h5')
model.save('model/my_model.keras')

# %%
# Evaluating the model from test set

results = model.evaluate(test_X, test_y, batch_size=256)
predictions = model.predict(test_X[:test_y.shape[0]])

j = 0 
count=0
for i in predictions:
    if(np.argmax(i)!=test_y[j]):
        count+=1
    j+=1
print(f"\n{count}/{test_y.shape[0]} Wrong Predictions,\n{test_y.shape[0]-count}/{test_y.shape[0]} Right Predictions,\nLoss = {results},")
print(f'Accuracy = {100*(test_y.shape[0]-count)/test_y.shape[0]}%')
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.1370
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step
#
# 225/10000 Wrong Predictions,
# 9775/10000 Right Predictions,
# Loss = 0.12062282860279083,
# Accuracy = 97.75%

# %%
# Plot Loss function with epochs

fig, ax = plt.subplots(1,1)
ax.plot(history.history['loss'], color='b', label="Training Loss")
ax.plot(history.history['val_loss'], color='r', label="Validation Loss")
legend = ax.legend(loc='best', shadow=True)

plt.xlabel('No. of epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
#Predicting a value from the test set (MNIST)

example = 138

image = test_X[example]
plt.imshow(test_X[example].reshape((28,28)), cmap=plt.get_cmap('gray'))

prediction = model.predict(image.reshape(1,784))  # prediction

print(f"\n\n Predictions = {prediction}")
print(f" Largest probability: {np.argmax(prediction)}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
#  Predictions = [[2.3022273e-16 1.7153047e-19 8.0243148e-25 7.0039267e-25 1.7260645e-17
#   6.5640633e-17 1.0000000e+00 9.7895089e-22 5.8071631e-19 8.1897626e-25]]
#  Largest probability: 6

# %%
#Predicting from own data
path = 'test_images/3_3.png'

image = tf.keras.utils.load_img(
            path,
            color_mode="grayscale",
            interpolation="nearest",
            keep_aspect_ratio=False,
        )

image = image.resize([28,28])
input_arr = tf.keras.utils.img_to_array(image)
input_arr = input_arr[:,:,0]

y = np.count_nonzero(input_arr>100)
if(y>500):
    input_arr=255-input_arr
    
plt.imshow(input_arr, cmap=plt.get_cmap('gray'))

scaler = MinMaxScaler()
arr = scaler.fit_transform(input_arr.reshape(1,784))
predictions = model.predict(arr)
print(f"\nPredicted Value = {np.argmax(predictions)}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Predicted Value = 5
